# %%
import pandas as pd
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import StratifiedKFold, ParameterSampler, cross_validate
from sklearn.metrics import make_scorer, fbeta_score
from sklearn.ensemble import RandomForestClassifier

# ======================================================================================
# F2 SCORE 중심 하이퍼파라미터 튜닝
# ======================================================================================
# F2 Score = (1 + 2²) × (Precision × Recall) / (2² × Precision + Recall)
#          = 5 × (Precision × Recall) / (4 × Precision + Recall)
#
# → Recall에 4배 가중치를 부여하므로 "False Negative"를 줄이는 것이 핵심!
# ======================================================================================

# -----------------------
# 0) 설정
# -----------------------
SEARCH_CONFIG = {
    "n_iter": 50,         # 탐색 횟수 증가 (F2 최적화를 위해)
    "cv": 5,              # 교차 검증 폴드 수
    "random_state": 42,
    "n_jobs": -1,
    "verbose": 1,
    "top_k_test": 20,     # Test셋 재검증할 상위 모델 개수
    
    # --- F2 Score 최적화를 위한 파라미터 공간 ---
    "params": {
        # 1) 트리 개수: 많을수록 안정적 (Recall 향상)
        "rf__n_estimators": [300, 500, 800, 1000, 1500],
        
        # 2) 트리 깊이: 깊을수록 소수 클래스 포착 가능 (Recall↑)
        #    None = 제한 없음 (과적합 위험 있지만 Recall 중요 시 유리)
        "rf__max_depth": [20, 30, 40, 50, None],
        
        # 3) 클래스 가중치: F2 Score에서 가장 중요!
        #    - "balanced": 클래스 비율의 역수로 가중치 부여
        #    - "balanced_subsample": 부트스트랩 샘플마다 가중치 재계산
        #    - 딕셔너리: 직접 가중치 조정 (예: {0: 1, 1: 5})
        "rf__class_weight": [
            "balanced", 
            "balanced_subsample",
            {0: 1, 1: 3},   # 소수 클래스에 3배 가중치
            {0: 1, 1: 5},   # 소수 클래스에 5배 가중치
            {0: 1, 1: 10},  # 소수 클래스에 10배 가중치 (극단적)
        ],
        
        # 4) 분할 최소 샘플 수: 작을수록 세밀한 분할 → Recall↑
        "rf__min_samples_split": [2, 5, 10, 20],
        
        # 5) 리프 노드 최소 샘플 수: 1~2로 설정 시 Recall 향상
        "rf__min_samples_leaf": [1, 2, 3],
        
        # 6) 피처 선택 방식
        "rf__max_features": ["sqrt", "log2", 0.5, 0.7],
        
        # 7) 부트스트랩: True 권장
        "rf__bootstrap": [True],
        
        # 8) 분할 기준: entropy가 불균형 데이터에 더 유리할 수 있음
        "rf__criterion": ["gini", "entropy"],
        
        # 9) 최소 불순도 감소: 0으로 설정 시 더 많은 분할 → Recall↑
        "rf__min_impurity_decrease": [0.0, 0.001, 0.005],
        
        # 10) 샘플 가중치 적용 시 oob_score 비활성화 권장
        "rf__oob_score": [False],
    }
}

# -----------------------
# 1) 데이터 로드
# -----------------------
train_df = pd.read_csv("../../../data/processed/train.csv")
test_df  = pd.read_csv("../../../data/processed/test.csv")

X_train = train_df.drop("Revenue", axis=1)
y_train = train_df["Revenue"].astype(int)

X_test  = test_df.drop("Revenue", axis=1)
y_test  = test_df["Revenue"].astype(int)

cat_cols = X_train.select_dtypes(include=["object", "category", "bool"]).columns.tolist()
num_cols = X_train.select_dtypes(include=["int64", "float64", "int32", "float32"]).columns.tolist()

print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")
print(f"Class distribution:\n{y_train.value_counts(normalize=True)}")

# -----------------------
# 2) 전처리
# -----------------------
numeric_tf = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
])

categorical_tf = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("ohe", OneHotEncoder(handle_unknown="ignore", sparse_output=False)),
])

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_tf, num_cols),
        ("cat", categorical_tf, cat_cols),
    ],
    remainder="drop",
    verbose_feature_names_out=False
)

# -----------------------
# 3) 모델 파이프라인
# -----------------------
rf = RandomForestClassifier(
    random_state=SEARCH_CONFIG["random_state"],
    n_jobs=SEARCH_CONFIG["n_jobs"],
)

pipe = Pipeline(steps=[
    ("preprocess", preprocess),
    ("rf", rf),
])

# -----------------------
# 4) F2 Score 정의 (beta=2)
# -----------------------
f2_scorer = make_scorer(fbeta_score, beta=2, zero_division=0)

scoring = {
    "acc": "accuracy",
    "prec": "precision",
    "rec": "recall",
    "f1": "f1",
    "f2": f2_scorer,  # ★ F2 Score 추가
    "roc_auc": "roc_auc",
}

cv = StratifiedKFold(
    n_splits=SEARCH_CONFIG["cv"],
    shuffle=True,
    random_state=SEARCH_CONFIG["random_state"],
)

# -----------------------
# 5) Manual Search Loop
# -----------------------
param_distributions = SEARCH_CONFIG["params"]

print(f"\n{'='*120}")
print(f"Generating {SEARCH_CONFIG['n_iter']} candidates for F2 Score optimization...")
print(f"{'='*120}\n")

param_list = list(ParameterSampler(
    param_distributions, 
    n_iter=SEARCH_CONFIG["n_iter"], 
    random_state=SEARCH_CONFIG["random_state"]
))

results = []

# 헤더 출력
print(f"{'Iter':<5} | {'F2':<7} | {'Rec':<7} | {'F1':<7} | {'AUC':<7} | {'Acc':<7} | {'Time(s)':<8} | Params")
print("-" * 150)

for i, params in enumerate(param_list):
    pipe.set_params(**params)
    
    cv_res = cross_validate(
        pipe, X_train, y_train, 
        cv=cv, scoring=scoring, 
        n_jobs=SEARCH_CONFIG["n_jobs"],
        return_train_score=False
    )
    
    # 집계
    mean_fit_time = cv_res['fit_time'].mean()
    mean_score_time = cv_res['score_time'].mean()
    
    mean_test_acc = cv_res['test_acc'].mean()
    mean_test_prec = cv_res['test_prec'].mean()
    mean_test_rec = cv_res['test_rec'].mean()
    mean_test_f1 = cv_res['test_f1'].mean()
    mean_test_f2 = cv_res['test_f2'].mean()  # ★
    std_test_f2 = cv_res['test_f2'].std()    # ★
    mean_test_roc_auc = cv_res['test_roc_auc'].mean()
    
    # 상태 출력 (F2 우선)
    print(
        f"{i+1:<5} | "
        f"{mean_test_f2:.4f}  | "
        f"{mean_test_rec:.4f}  | "
        f"{mean_test_f1:.4f}  | "
        f"{mean_test_roc_auc:.4f}  | "
        f"{mean_test_acc:.4f}  | "
        f"{mean_fit_time:6.2f}   | "
        f"{params}"
    )
    
    # 저장
    row = {
        "mean_fit_time": mean_fit_time,
        "mean_score_time": mean_score_time,
        "mean_test_acc": mean_test_acc,
        "mean_test_prec": mean_test_prec,
        "mean_test_rec": mean_test_rec,
        "mean_test_f1": mean_test_f1,
        "mean_test_f2": mean_test_f2,      # ★
        "std_test_f2": std_test_f2,        # ★
        "mean_test_roc_auc": mean_test_roc_auc,
    }
    
    for k, v in params.items():
        row[f"param_{k}"] = v
        
    results.append(row)

# -----------------------
# 6) CV Results DataFrame
# -----------------------
cv_results = pd.DataFrame(results)

if not cv_results.empty:
    # F2 기준 랭킹
    cv_results["rank_test_f2"] = cv_results["mean_test_f2"].rank(ascending=False, method="min").astype(int)

    param_cols = [c for c in cv_results.columns if c.startswith("param_")]
    keep_cols = (
        ["rank_test_f2", "mean_fit_time"] +
        param_cols +
        ["mean_test_f2", "std_test_f2",      # ★ F2 우선
         "mean_test_rec", "mean_test_f1",    # Recall, F1 순서
         "mean_test_prec", "mean_test_acc", "mean_test_roc_auc"]
    )

    leaderboard_cv = (
        cv_results[keep_cols]
        .sort_values(["mean_test_f2", "mean_test_rec"], ascending=False)  # ★ F2 → Recall 순
        .reset_index(drop=True)
    )

    print("\n" + "="*150)
    print("TOP 30 Models by F2 Score (Cross-Validation)")
    print("="*150 + "\n")
    
    # 표 출력
    display(leaderboard_cv.head(30).style.format(precision=4))
    
    # -----------------------
    # 7) Test Set 평가 (상위 모델만)
    # -----------------------
    print(f"\n{'='*120}")
    print(f"Evaluating Top {SEARCH_CONFIG['top_k_test']} models on Test Set...")
    print(f"{'='*120}\n")
    
    test_results = []
    
    for idx in range(min(SEARCH_CONFIG['top_k_test'], len(leaderboard_cv))):
        row = leaderboard_cv.iloc[idx]
        
        # 파라미터 추출
        test_params = {}
        for col in param_cols:
            param_name = col.replace("param_", "")
            test_params[param_name] = row[col]
        
        # 모델 재학습
        pipe.set_params(**test_params)
        pipe.fit(X_train, y_train)
        
        # Test 예측
        y_pred = pipe.predict(X_test)
        y_proba = pipe.predict_proba(X_test)[:, 1]
        
        # 메트릭 계산
        test_acc = accuracy_score(y_test, y_pred)
        test_prec = precision_score(y_test, y_pred, zero_division=0)
        test_rec = recall_score(y_test, y_pred, zero_division=0)
        test_f1 = f1_score(y_test, y_pred, zero_division=0)
        test_f2 = fbeta_score(y_test, y_pred, beta=2, zero_division=0)  # ★
        test_auc = roc_auc_score(y_test, y_proba)
        
        test_results.append({
            "rank_cv": idx + 1,
            "cv_f2": row["mean_test_f2"],
            "test_f2": test_f2,      # ★
            "test_rec": test_rec,
            "test_f1": test_f1,
            "test_prec": test_prec,
            "test_acc": test_acc,
            "test_auc": test_auc,
            **test_params
        })
    
    test_df_results = pd.DataFrame(test_results)
    test_df_results["rank_test_f2"] = test_df_results["test_f2"].rank(ascending=False, method="min").astype(int)
    
    test_leaderboard = (
        test_df_results
        .sort_values(["test_f2", "test_rec"], ascending=False)
        .reset_index(drop=True)
    )
    
    print("\n" + "="*150)
    print("TOP 20 Models by F2 Score (Test Set)")
    print("="*150 + "\n")
    
    display(test_leaderboard.head(20).style.format(precision=4))
    
    # Best Model
    best_idx = test_leaderboard.iloc[0]
    print(f"\n{'='*120}")
    print(f"BEST MODEL (F2 Score: {best_idx['test_f2']:.4f})")
    print(f"{'='*120}")
    print(f"  CV F2:     {best_idx['cv_f2']:.4f}")
    print(f"  Test F2:   {best_idx['test_f2']:.4f}")
    print(f"  Test Rec:  {best_idx['test_rec']:.4f}")
    print(f"  Test F1:   {best_idx['test_f1']:.4f}")
    print(f"  Test Prec: {best_idx['test_prec']:.4f}")
    print(f"  Test Acc:  {best_idx['test_acc']:.4f}")
    print(f"  Test AUC:  {best_idx['test_auc']:.4f}")
    print(f"\nParameters:")
    for col in param_cols:
        param_name = col.replace("param_", "")
        if param_name in best_idx:
            print(f"  {param_name}: {best_idx[param_name]}")
    
else:
    print("No results found.")
# Out:
# Train shape: (9864, 18), Test shape: (2466, 18)
# Class distribution:
# Revenue
# 0    0.845296
# 1    0.154704
# Name: proportion, dtype: float64
#
# ========================================================================================================================
# Generating 50 candidates for F2 Score optimization...
# ========================================================================================================================
#
# Iter  | F2      | Rec     | F1      | AUC     | Acc     | Time(s)  | Params
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1     | 0.7460  | 0.8067  | 0.6705  | 0.9247  | 0.8772  |   1.96   | {'rf__oob_score': False, 'rf__n_estimators': 300, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 0.7, 'rf__max_depth': 30, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 2     | 0.7521  | 0.8394  | 0.6508  | 0.9056  | 0.8605  |   0.55   | {'rf__oob_score': False, 'rf__n_estimators': 300, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'sqrt', 'rf__max_depth': 30, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 3     | 0.7543  | 0.8421  | 0.6526  | 0.9315  | 0.8611  |  13.23   | {'rf__oob_score': False, 'rf__n_estimators': 1500, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 0.5, 'rf__max_depth': 20, 'rf__criterion': 'entropy', 'rf__class_weight': 'balanced_subsample', 'rf__bootstrap': True}
# 4     | 0.7557  | 0.8440  | 0.6534  | 0.9313  | 0.8613  |   2.30   | {'rf__oob_score': False, 'rf__n_estimators': 300, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 0.5, 'rf__max_depth': 50, 'rf__criterion': 'entropy', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 5     | 0.7201  | 0.7569  | 0.6714  | 0.9194  | 0.8852  |   0.90   | {'rf__oob_score': False, 'rf__n_estimators': 300, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 'log2', 'rf__max_depth': 50, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 6     | 0.6083  | 0.5852  | 0.6470  | 0.9319  | 0.9012  |   9.15   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 0.5, 'rf__max_depth': 20, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 5}, 'rf__bootstrap': True}
# 7     | 0.5671  | 0.5328  | 0.6278  | 0.9325  | 0.9023  |   4.10   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 'log2', 'rf__max_depth': 40, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 8     | 0.7544  | 0.8545  | 0.6418  | 0.9211  | 0.8524  |   1.15   | {'rf__oob_score': False, 'rf__n_estimators': 300, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 'log2', 'rf__max_depth': 40, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 9     | 0.7100  | 0.7235  | 0.6911  | 0.9350  | 0.8998  |   9.13   | {'rf__oob_score': False, 'rf__n_estimators': 1500, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 'sqrt', 'rf__max_depth': 30, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 10    | 0.7535  | 0.8493  | 0.6446  | 0.9203  | 0.8550  |   2.93   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 'log2', 'rf__max_depth': 50, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 11    | 0.7536  | 0.8414  | 0.6518  | 0.9288  | 0.8608  |   1.89   | {'rf__oob_score': False, 'rf__n_estimators': 500, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 'log2', 'rf__max_depth': 40, 'rf__criterion': 'entropy', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 12    | 0.7233  | 0.7615  | 0.6729  | 0.9195  | 0.8853  |   2.75   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 'log2', 'rf__max_depth': None, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 13    | 0.7098  | 0.7457  | 0.6622  | 0.9115  | 0.8822  |   3.69   | {'rf__oob_score': False, 'rf__n_estimators': 1500, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'log2', 'rf__max_depth': 40, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 14    | 0.7368  | 0.7726  | 0.6892  | 0.9345  | 0.8920  |  14.35   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 0.7, 'rf__max_depth': None, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 5}, 'rf__bootstrap': True}
# 15    | 0.7412  | 0.7857  | 0.6835  | 0.9346  | 0.8872  |   7.09   | {'rf__oob_score': False, 'rf__n_estimators': 500, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 0.7, 'rf__max_depth': 50, 'rf__criterion': 'entropy', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 16    | 0.7535  | 0.8355  | 0.6570  | 0.9191  | 0.8648  |   1.03   | {'rf__oob_score': False, 'rf__n_estimators': 300, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'sqrt', 'rf__max_depth': 50, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 5}, 'rf__bootstrap': True}
# 17    | 0.7420  | 0.7877  | 0.6831  | 0.9354  | 0.8867  |  11.15   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 0.5, 'rf__max_depth': 20, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 5}, 'rf__bootstrap': True}
# 18    | 0.6753  | 0.6717  | 0.6810  | 0.9342  | 0.9026  |   4.36   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 'log2', 'rf__max_depth': 30, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 19    | 0.7322  | 0.7575  | 0.6975  | 0.9358  | 0.8981  |   5.86   | {'rf__oob_score': False, 'rf__n_estimators': 500, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 0.5, 'rf__max_depth': 20, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 20    | 0.7002  | 0.7071  | 0.6904  | 0.9331  | 0.9018  |  11.88   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 0.7, 'rf__max_depth': 50, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 21    | 0.6510  | 0.6376  | 0.6723  | 0.9332  | 0.9038  |   7.57   | {'rf__oob_score': False, 'rf__n_estimators': 1500, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 'log2', 'rf__max_depth': 20, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 22    | 0.7158  | 0.7313  | 0.6939  | 0.9349  | 0.9000  |  12.32   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 0.5, 'rf__max_depth': 30, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 23    | 0.7537  | 0.8892  | 0.6137  | 0.9304  | 0.8267  |   7.36   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 0.5, 'rf__max_depth': None, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 10}, 'rf__bootstrap': True}
# 24    | 0.7531  | 0.8335  | 0.6581  | 0.9348  | 0.8659  |  11.98   | {'rf__oob_score': False, 'rf__n_estimators': 1500, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 0.5, 'rf__max_depth': 40, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 25    | 0.6231  | 0.6055  | 0.6517  | 0.9309  | 0.8998  |  12.71   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 0.7, 'rf__max_depth': 30, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 26    | 0.7269  | 0.7536  | 0.6906  | 0.9329  | 0.8954  |   7.24   | {'rf__oob_score': False, 'rf__n_estimators': 500, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 0.7, 'rf__max_depth': 50, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 10}, 'rf__bootstrap': True}
# 27    | 0.7087  | 0.7208  | 0.6915  | 0.9340  | 0.9003  |  26.70   | {'rf__oob_score': False, 'rf__n_estimators': 1500, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 0.7, 'rf__max_depth': 20, 'rf__criterion': 'entropy', 'rf__class_weight': 'balanced_subsample', 'rf__bootstrap': True}
# 28    | 0.7476  | 0.8178  | 0.6628  | 0.9243  | 0.8708  |   3.52   | {'rf__oob_score': False, 'rf__n_estimators': 500, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 0.7, 'rf__max_depth': None, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 29    | 0.7548  | 0.8440  | 0.6516  | 0.9289  | 0.8603  |   1.28   | {'rf__oob_score': False, 'rf__n_estimators': 300, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 'log2', 'rf__max_depth': 20, 'rf__criterion': 'entropy', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 30    | 0.7508  | 0.8932  | 0.6060  | 0.9155  | 0.8203  |   1.81   | {'rf__oob_score': False, 'rf__n_estimators': 300, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 0.5, 'rf__max_depth': 40, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 10}, 'rf__bootstrap': True}
# 31    | 0.7357  | 0.7798  | 0.6784  | 0.9254  | 0.8854  |   2.90   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 'sqrt', 'rf__max_depth': 20, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 32    | 0.7458  | 0.8152  | 0.6617  | 0.9038  | 0.8708  |   3.18   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'sqrt', 'rf__max_depth': 20, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 5}, 'rf__bootstrap': True}
# 33    | 0.6310  | 0.6140  | 0.6584  | 0.9310  | 0.9014  |  14.27   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 0.7, 'rf__max_depth': None, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced_subsample', 'rf__bootstrap': True}
# 34    | 0.7527  | 0.8388  | 0.6526  | 0.9042  | 0.8617  |   3.30   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'sqrt', 'rf__max_depth': 40, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced_subsample', 'rf__bootstrap': True}
# 35    | 0.7470  | 0.8159  | 0.6635  | 0.9230  | 0.8717  |   6.89   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 0.5, 'rf__max_depth': 30, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced_subsample', 'rf__bootstrap': True}
# 36    | 0.7363  | 0.7733  | 0.6875  | 0.9338  | 0.8909  |   3.37   | {'rf__oob_score': False, 'rf__n_estimators': 500, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 'log2', 'rf__max_depth': 20, 'rf__criterion': 'entropy', 'rf__class_weight': 'balanced_subsample', 'rf__bootstrap': True}
# 37    | 0.7458  | 0.8152  | 0.6617  | 0.9038  | 0.8708  |   2.30   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'sqrt', 'rf__max_depth': 50, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 5}, 'rf__bootstrap': True}
# 38    | 0.7552  | 0.8348  | 0.6608  | 0.9347  | 0.8673  |   6.44   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 0.5, 'rf__max_depth': 50, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 39    | 0.7549  | 0.8296  | 0.6652  | 0.9347  | 0.8706  |   9.07   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 0.5, 'rf__max_depth': 40, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 5}, 'rf__bootstrap': True}
# 40    | 0.7162  | 0.7339  | 0.6913  | 0.9334  | 0.8984  |  21.56   | {'rf__oob_score': False, 'rf__n_estimators': 1500, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 0.7, 'rf__max_depth': 50, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 41    | 0.7159  | 0.7562  | 0.6631  | 0.9039  | 0.8810  |   1.46   | {'rf__oob_score': False, 'rf__n_estimators': 500, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'sqrt', 'rf__max_depth': 20, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 42    | 0.7530  | 0.8218  | 0.6695  | 0.9348  | 0.8742  |   5.18   | {'rf__oob_score': False, 'rf__n_estimators': 300, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 0.7, 'rf__max_depth': None, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 10}, 'rf__bootstrap': True}
# 43    | 0.7374  | 0.7739  | 0.6890  | 0.9345  | 0.8917  |   7.53   | {'rf__oob_score': False, 'rf__n_estimators': 500, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 0.7, 'rf__max_depth': 30, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 5}, 'rf__bootstrap': True}
# 44    | 0.7521  | 0.8394  | 0.6508  | 0.9056  | 0.8605  |   0.86   | {'rf__oob_score': False, 'rf__n_estimators': 300, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'sqrt', 'rf__max_depth': 40, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 45    | 0.7510  | 0.8538  | 0.6361  | 0.9117  | 0.8487  |   2.81   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'log2', 'rf__max_depth': 20, 'rf__criterion': 'entropy', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 46    | 0.7469  | 0.8165  | 0.6625  | 0.9036  | 0.8710  |   4.02   | {'rf__oob_score': False, 'rf__n_estimators': 1500, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 3, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'sqrt', 'rf__max_depth': 50, 'rf__criterion': 'gini', 'rf__class_weight': {0: 1, 1: 5}, 'rf__bootstrap': True}
# 47    | 0.7107  | 0.7235  | 0.6926  | 0.9350  | 0.9005  |   4.99   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.0, 'rf__max_features': 'sqrt', 'rf__max_depth': 40, 'rf__criterion': 'entropy', 'rf__class_weight': {0: 1, 1: 3}, 'rf__bootstrap': True}
# 48    | 0.7505  | 0.8447  | 0.6430  | 0.9007  | 0.8548  |   1.24   | {'rf__oob_score': False, 'rf__n_estimators': 500, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'log2', 'rf__max_depth': 30, 'rf__criterion': 'gini', 'rf__class_weight': 'balanced', 'rf__bootstrap': True}
# 49    | 0.7541  | 0.8506  | 0.6447  | 0.9175  | 0.8548  |   4.49   | {'rf__oob_score': False, 'rf__n_estimators': 1000, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 1, 'rf__min_impurity_decrease': 0.005, 'rf__max_features': 'sqrt', 'rf__max_depth': 30, 'rf__criterion': 'entropy', 'rf__class_weight': 'balanced_subsample', 'rf__bootstrap': True}
# 50    | 0.7442  | 0.7942  | 0.6804  | 0.9352  | 0.8842  |  10.02   | {'rf__oob_score': False, 'rf__n_estimators': 800, 'rf__min_samples_split': 20, 'rf__min_samples_leaf': 2, 'rf__min_impurity_decrease': 0.001, 'rf__max_features': 0.5, 'rf__max_depth': 50, 'rf__criterion': 'entropy', 'rf__class_weight': 'balanced_subsample', 'rf__bootstrap': True}
#
# ======================================================================================================================================================
# TOP 30 Models by F2 Score (Cross-Validation)
# ======================================================================================================================================================
# <style type="text/css">
# </style>
# <table id="T_6e4f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e4f2_level0_col0" class="col_heading level0 col0" >rank_test_f2</th>
#       <th id="T_6e4f2_level0_col1" class="col_heading level0 col1" >mean_fit_time</th>
#       <th id="T_6e4f2_level0_col2" class="col_heading level0 col2" >param_rf__oob_score</th>
#       <th id="T_6e4f2_level0_col3" class="col_heading level0 col3" >param_rf__n_estimators</th>
#       <th id="T_6e4f2_level0_col4" class="col_heading level0 col4" >param_rf__min_samples_split</th>
#       <th id="T_6e4f2_level0_col5" class="col_heading level0 col5" >param_rf__min_samples_leaf</th>
#       <th id="T_6e4f2_level0_col6" class="col_heading level0 col6" >param_rf__min_impurity_decrease</th>
#       <th id="T_6e4f2_level0_col7" class="col_heading level0 col7" >param_rf__max_features</th>
#       <th id="T_6e4f2_level0_col8" class="col_heading level0 col8" >param_rf__max_depth</th>
#       <th id="T_6e4f2_level0_col9" class="col_heading level0 col9" >param_rf__criterion</th>
#       <th id="T_6e4f2_level0_col10" class="col_heading level0 col10" >param_rf__class_weight</th>
#       <th id="T_6e4f2_level0_col11" class="col_heading level0 col11" >param_rf__bootstrap</th>
#       <th id="T_6e4f2_level0_col12" class="col_heading level0 col12" >mean_test_f2</th>
#       <th id="T_6e4f2_level0_col13" class="col_heading level0 col13" >std_test_f2</th>
#       <th id="T_6e4f2_level0_col14" class="col_heading level0 col14" >mean_test_rec</th>
#       <th id="T_6e4f2_level0_col15" class="col_heading level0 col15" >mean_test_f1</th>
#       <th id="T_6e4f2_level0_col16" class="col_heading level0 col16" >mean_test_prec</th>
#       <th id="T_6e4f2_level0_col17" class="col_heading level0 col17" >mean_test_acc</th>
#       <th id="T_6e4f2_level0_col18" class="col_heading level0 col18" >mean_test_roc_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e4f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e4f2_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6e4f2_row0_col1" class="data row0 col1" >2.2995</td>
#       <td id="T_6e4f2_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_6e4f2_row0_col3" class="data row0 col3" >300</td>
#       <td id="T_6e4f2_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_6e4f2_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_6e4f2_row0_col6" class="data row0 col6" >0.0050</td>
#       <td id="T_6e4f2_row0_col7" class="data row0 col7" >0.5000</td>
#       <td id="T_6e4f2_row0_col8" class="data row0 col8" >50.0000</td>
#       <td id="T_6e4f2_row0_col9" class="data row0 col9" >entropy</td>
#       <td id="T_6e4f2_row0_col10" class="data row0 col10" >balanced</td>
#       <td id="T_6e4f2_row0_col11" class="data row0 col11" >True</td>
#       <td id="T_6e4f2_row0_col12" class="data row0 col12" >0.7557</td>
#       <td id="T_6e4f2_row0_col13" class="data row0 col13" >0.0124</td>
#       <td id="T_6e4f2_row0_col14" class="data row0 col14" >0.8440</td>
#       <td id="T_6e4f2_row0_col15" class="data row0 col15" >0.6534</td>
#       <td id="T_6e4f2_row0_col16" class="data row0 col16" >0.5333</td>
#       <td id="T_6e4f2_row0_col17" class="data row0 col17" >0.8613</td>
#       <td id="T_6e4f2_row0_col18" class="data row0 col18" >0.9313</td>
#     </tr>
#     <tr>
#       <th id="T_6e4f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e4f2_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6e4f2_row1_col1" class="data row1 col1" >6.4370</td>
#       <td id="T_6e4f2_row1_col2" class="data row1 col2" >False</td>
#       <td id="T_6e4f2_row1_col3" class="data row1 col3" >800</td>
#       <td id="T_6e4f2_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_6e4f2_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_6e4f2_row1_col6" class="data row1 col6" >0.0010</td>
#       <td id="T_6e4f2_row1_col7" class="data row1 col7" >0.5000</td>
#       <td id="T_6e4f2_row1_col8" class="data row1 col8" >50.0000</td>
#       <td id="T_6e4f2_row1_col9" class="data row1 col9" >gini</td>
#       <td id="T_6e4f2_row1_col10" class="data row1 col10" >balanced</td>
#       <td id="T_6e4f2_row1_col11" class="data row1 col11" >True</td>
#       <td id="T_6e4f2_row1_col12" class="data row1 col12" >0.7552</td>
#       <td id="T_6e4f2_row1_col13" class="data row1 col13" >0.0123</td>
#       <td id="T_6e4f2_row1_col14" class="data row1 col14" >0.8348</td>
#       <td id="T_6e4f2_row1_col15" class="data row1 col15" >0.6608</td>
#       <td id="T_6e4f2_row1_col16" class="data row1 col16" >0.5472</td>
#       <td id="T_6e4f2_row1_col17" class="data row1 col17" >0.8673</td>
#       <td id="T_6e4f2_row1_col18" class="data row1 col18" >0.9347</td>
#     </tr>
#     <tr>
#       <th id="T_6e4f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e4f2_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_6e4f2_row2_col1" class="data row2 col1" >9.0659</td>
#       <td id="T_6e4f2_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_6e4f2_row2_col3" class="data row2 col3" >1000</td>
#       <td id="T_6e4f2_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_6e4f2_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_6e4f2_row2_col6" class="data row2 col6" >0.0010</td>
#       <td id="T_6e4f2_row2_col7" class="data row2 col7" >0.5000</td>
#       <td id="T_6e4f2_row2_col8" class="data row2 col8" >40.0000</td>
#       <td id="T_6e4f2_row2_col9" class="data row2 col9" >gini</td>
#       <td id="T_6e4f2_row2_col10" class="data row2 col10" >{0: 1, 1: 5}</td>
#       <td id="T_6e4f2_row2_col11" class="data row2 col11" >True</td>
#       <td id="T_6e4f2_row2_col12" class="data row2 col12" >0.7549</td>
#       <td id="T_6e4f2_row2_col13" class="data row2 col13" >0.0097</td>
#       <td id="T_6e4f2_row2_col14" class="data row2 col14" >0.8296</td>
#       <td id="T_6e4f2_row2_col15" class="data row2 col15" >0.6652</td>
#       <td id="T_6e4f2_row2_col16" class="data row2 col16" >0.5557</td>
#       <td id="T_6e4f2_row2_col17" class="data row2 col17" >0.8706</td>
#       <td id="T_6e4f2_row2_col18" class="data row2 col18" >0.9347</td>
#     </tr>
#     <tr>
#       <th id="T_6e4f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e4f2_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_6e4f2_row3_col1" class="data row3 col1" >1.2796</td>
#       <td id="T_6e4f2_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_6e4f2_row3_col3" class="data row3 col3" >300</td>
#       <td id="T_6e4f2_row3_col4" class="data row3 col4" >10</td>
#       <td id="T_6e4f2_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_6e4f2_row3_col6" class="data row3 col6" >0.0010</td>
#       <td id="T_6e4f2_row3_col7" class="data row3 col7" >log2</td>
#       <td id="T_6e4f2_row3_col8" class="data row3 col8" >20.0000</td>
#       <td id="T_6e4f2_row3_col9" class="data row3 col9" >entropy</td>
#       <td id="T_6e4f2_row3_col10" class="data row3 col10" >balanced</td>
#       <td id="T_6e4f2_row3_col11" class="data row3 col11" >True</td>
#       <td id="T_6e4f2_row3_col12" class="data row3 col12" >0.7548</td>
#       <td id="T_6e4f2_row3_col13" class="data row3 col13" >0.0149</td>
#       <td id="T_6e4f2_row3_col14" class="data row3 col14" >0.8440</td>
#       <td id="T_6e4f2_row3_col15" class="data row3 col15" >0.6516</td>
#       <td id="T_6e4f2_row3_col16" class="data row3 col16" >0.5309</td>
#       <td id="T_6e4f2_row3_col17" class="data row3 col17" >0.8603</td>
#       <td id="T_6e4f2_row3_col18" class="data row3 col18" >0.9289</td>
#     </tr>
#     <tr>
#       <th id="T_6e4f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e4f2_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_6e4f2_row4_col1" class="data row4 col1" >1.1527</td>
#       <td id="T_6e4f2_row4_col2" class="data row4 col2" >False</td>
#       <td id="T_6e4f2_row4_col3" class="data row4 col3" >300</td>
#       <td id="T_6e4f2_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_6e4f2_row4_col5" class="data ro
# ========================================================================================================================
# Evaluating Top 20 models on Test Set...
# ========================================================================================================================
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[1], line 273
#     271 # 모델 재학습
#     272 pipe.set_params(**test_params)
# --> 273 pipe.fit(X_train, y_train)
#     275 # Test 예측
#     276 y_pred = pipe.predict(X_test)
#
# File /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/pipeline.py:663, in Pipeline.fit(self, X, y, **params)
#     657     if self._final_estimator != "passthrough":
#     658         last_step_params = self._get_metadata_for_step(
#     659             step_idx=len(self) - 1,
#     660             step_params=routed_params[self.steps[-1][0]],
#     661             all_params=params,
#     662         )
# --> 663         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     665 return self
#
# File /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/base.py:1358, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1353 partial_fit_and_fitted = (
#    1354     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1355 )
#    1357 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
#    1365     return fit_method(estimator, *args, **kwargs)
#
# File /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/base.py:471, in BaseEstimator._validate_params(self)
#     463 def _validate_params(self):
#     464     """Validate types and values of constructor parameters
#     465
#     466     The expected type and values must be defined in the `_parameter_constraints`
#    (...)    469     accepted constraints.
#     470     """
# --> 471     validate_parameter_constraints(
#     472         self._parameter_constraints,
#     473         self.get_params(deep=False),
#     474         caller_name=self.__class__.__name__,
#     475     )
#
# File /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'max_depth' parameter of RandomForestClassifier must be an int in the range [1, inf) or None. Got 50.0 instead.
